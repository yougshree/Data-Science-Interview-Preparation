# %% [markdown]
# <a href="https://colab.research.google.com/github/yougshree/Data-Science-Interview-Preparation/blob/main/Pandas%20Interview%20Preparation/Practice_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 1.Create dataframe
df= pd.DataFrame([11, 20, 30],columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        20
# 2        30

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data= {
    'Name': ['Mina', 'Dina', 'Rina', 'Simu'],
    'Age': [22, 32, 40, 38],
    'Salary':[20000, 32000, 380000, 34000]
}

# %%
df= pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  Salary
# 0  Mina   22   20000
# 1  Dina   32   32000
# 2  Rina   40  380000
# 3  Simu   38   34000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#Basic

# %%
df.head() #top five
# Out:
#    Name  Age  Salary
# 0  Mina   22   20000
# 1  Dina   32   32000
# 2  Rina   40  380000
# 3  Simu   38   34000

# %%
df.head(10) # top ten
# Out:
#    Name  Age  Salary
# 0  Mina   22   20000
# 1  Dina   32   32000
# 2  Rina   40  380000
# 3  Simu   38   34000

# %%
df.tail() # last five
# Out:
#    Name  Age  Salary
# 0  Mina   22   20000
# 1  Dina   32   32000
# 2  Rina   40  380000
# 3  Simu   38   34000

# %%
df.shape # find total col and rows
# Out:
# (4, 3)

# %%
df.columns # columns name
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns= {'Salary': 'Monthly_Salary'}, inplace= True) # permanetly change by using true

# %%
df
# Out:
#    Name  Age  Salary
# 0  Mina   22   20000
# 1  Dina   32   32000
# 2  Rina   40  380000
# 3  Simu   38   34000

# %%
df.info() #information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age         Salary
# count   4.000000       4.000000
# mean   33.000000  116500.000000
# std     8.082904  175775.424903
# min    22.000000   20000.000000
# 25%    29.500000   29000.000000
# 50%    35.000000   33000.000000
# 75%    38.500000  120500.000000
# max    40.000000  380000.000000

# %%
#3 save and load data from csv
df.to_csv('Test_data.csv', index='False') #index value will be deleted

# %%
df1= pd.read_csv('Test_data.csv')
print(df1)
import pandas as pd
# Out:
#    Unnamed: 0  Name  Age  Salary
# 0           0  Mina   22   20000
# 1           1  Dina   32   32000
# 2           2  Rina   40  380000
# 3           3  Simu   38   34000

# %%
#4 rows & columns selection

# %%
#slect single column
df1[['Name']]
# Out:
#    Name
# 0  Mina
# 1  Dina
# 2  Rina
# 3  Simu

# %%
#single multiple
df1[['Name', 'Salary']]
# Out:
#    Name  Salary
# 0  Mina   20000
# 1  Dina   32000
# 2  Rina  380000
# 3  Simu   34000

# %%
#select row
df1
# Out:
#    Unnamed: 0  Name  Age  Salary
# 0           0  Mina   22   20000
# 1           1  Dina   32   32000
# 2           2  Rina   40  380000
# 3           3  Simu   38   34000

# %%
# rows
df1.loc[(df1.Name=='Dina')& (df1.Monthly_Salary>=30000)]
df1 # error answer
# Out:
#    Name  Age  Monthly_Salary
# 0  Mina   22           20000
# 1  Dina   32           32000
# 2  Rina   40          380000
# 3  Simu   38           34000

# %%
#index value
df1.iloc[0]
# Out:
# Name               Mina
# Age                  22
# Monthly_Salary    20000
# Name: 0, dtype: object

# %%
df1.iloc[0:2] # give first two array start count from 0. 0->1, 1->2
# Out:
#    Name  Age  Monthly_Salary
# 0  Mina   22           20000
# 1  Dina   32           32000

# %%
df.loc[0:2] #array start from 0
# Out:
#    Name  Age  Monthly_Salary
# 0  Mina   22           20000
# 1  Dina   32           32000
# 2  Rina   40          380000

# %%
#filter dataframe
df1= [df1['Age']>= 18]
df1
# Out:
# [0    True
#  1    True
#  2    True
#  3    True
#  Name: Age, dtype: bool]

# %%
df1= (df1(['Age']>= 18) & (df1['Monthly_Salary']>=30000))
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8162/2306266583.py in <cell line: 0>()
# ----> 1 df1= (df1(['Age']>= 18) & (df1['Monthly_Salary']>=30000))
#       2 df1
#
# TypeError: '>=' not supported between instances of 'list' and 'int'

# %%
#5 dataframe selection
